# %%
import pandas as pd

# %%
library membaca csv

# %%
DataTest = pd.read_csv('C:\Users\Mirza\Download\test.csv')

# %% [markdown]
# membuat variabel baru sebagai variabel file test.csv yang telah dibaca

# %% [markdown]
# Misi Anda adalah menentukan, apa peran dari masing-masing hero yang membutuhkan bantuan dari program Anda, dengan aturan sebagai berikut secara berurutan (hero mendapatkan peran yang paling awal memenuhi syarat):
#
#     Heroes yang memiliki movementSpeed >= 270, akan mendapat peran sebagai MARKSMAN (huruf kapital semua)
#     Heroes dengan mana >= 500, akan mendapat peran sebagai MAGE (huruf kapital semua)
#     Heroes dengan armor >= 25, akan mendapat peran sebagai TANK (huruf kapital semua)
#     Heroes dengan physicalAttack >= 121, akan mendapat peran sebagai ASSASSIN (huruf kapital semua)
#     Heroes dengan hp >= 2580, akan mendapat peran sebagai FIGHTER (huruf kapital semua)
#     Heroes lainnya akan mendapat peran sebagai SUPPORT (huruf kapital semua)

# %% [markdown]
# algoritma

# %%
Role = []
for i in range(len(dt)):
    if dt["movementSpeed"][i] >= 270:
        Role.append("MARKSMAN")
    elif dt["mana"][i] >= 500:
        Role.append("MAGE")
    elif dt["armor"][i] >= 25:
        Role.append("TANK")
    elif dt["physicalAttack"][i] >= 121:
        Role.append("ASSASSIN")
    elif dt["hp"][i] >= 2580:
        Role.append("FIGHTER")
    else:
        Role.append("SUPPORT")

# %% [markdown]
# klasifikasi role heroes

# %%
dataBaru = pd.DataFrame({"name" : dt["name"],"role" : Role})

# %% [markdown]
# membuat data baru dengan keluaran nama dan role dari masing2 heroes

# %%
dataBaru.to_csv("prediction.csv", index = False)

# %% [markdown]
# ^ mengkonversi data baru menjadi keluaran file berbentuk ".csv"

# %%
dataBaru
# Out:
#            name      role
# 0         Layla  MARKSMAN
# 1       Cyclops      MAGE
# 2      Minotaur      TANK
# 3         Saber  ASSASSIN
# 4         Roger   FIGHTER
# 5          Nana   SUPPORT
# 6          Akai   FIGHTER
# 7         Alice   SUPPORT
# 8         Alpha  ASSASSIN
# 9       Alucard   FIGHTER
# 10        Argus  ASSASSIN
# 11       Aurora      MAGE
# 12      Balmond   FIGHTER
# 13         Bane   FIGHTER
# 14        Bruno   SUPPORT
# 15         Chou  ASSASSIN
# 16        Clint  ASSASSIN
# 17       Diggie   SUPPORT
# 18        Estes      MAGE
# 19       Eudora   SUPPORT
# 20        Fanny  MARKSMAN
# 21       Franco      TANK
# 22        Freya   FIGHTER
# 23    Gatotkaca   FIGHTER
# 24         Gord      MAGE
# 25        Grock  ASSASSIN
# 26       Harley   SUPPORT
# 27     Hayabusa   SUPPORT
# 28       Helcur  ASSASSIN
# 29        Hilda  ASSASSIN
# 30        Hylos   FIGHTER
# 31      Irithel   SUPPORT
# 32      Johnson      TANK
# 33       Kagura      MAGE
# 34       Karina  ASSASSIN
# 35       Karrie   SUPPORT
# 36     Lancelot  ASSASSIN
# 37    Lapu-lapu   FIGHTER
# 38       Lolita      TANK
# 39         Miya   SUPPORT
# 40       Moskov  ASSASSIN
# 41      Natalia  ASSASSIN
# 42       Odette   SUPPORT
# 43       Pharsa   SUPPORT
# 44      Rafaela      MAGE
# 45         Ruby   FIGHTER
# 46   Sun Wukong   FIGHTER
# 47      Tigreal      TANK
# 48       Vexana   SUPPORT
# 49  Yi Sun-Shin   SUPPORT
# 50     Yun Zhao  MARKSMAN
# 51        Zhask   SUPPORT

# %% [markdown]
# output
